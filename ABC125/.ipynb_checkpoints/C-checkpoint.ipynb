# %%
import time
import sys
start = time.time()
def gcd(a, b):
    if b == 0:
        return a
    return gcd(b, a%b)

N = int(input())
#N = int(1e+5)
integers = list(map(int, input().split()))
#integers = list(set([random.randint(1, N) for i in range(N)]))
if len(integers) == 1:
    print(integers[0])
    sys.exit()
    
integers.sort()
d
gcds = [integers[0]]
for integer in integers[1:]:
    gcds.append(gcd(integer, gcds[-1]))
    
ans = [gcds[-2]]
for i in range(len(gcds) - 2):
    ans.append(gcd(gcds[i], integers[i + 2]))

temp = integers[1]
for integer in integers[2:]:
    temp = gcd(temp, integer)
ans.append(temp)
print(max(ans))
print(time.time() - start)
# Out:
# 2
# 10000 10000
# 10000
# 3.8134970664978027

# %%
import random
a = 100000
print(' '.join(list(map(str, [random.randint(1, a) for i in range(a)]))))
# Out:
# 38282 47471 27264 49528 45007 68751 26230 20496 95736 52809 40222 21610 75896 35899 34464 29256 92626 67057 81272 28195 30461 38683 84996 98467 96007 52360 36649 79587 79396 47200 12959 64226 64706 3761 10276 6949 40473 39454 14087 32653 96987 39679 84075 59130 56307 90925 23986 75732 69187 89893 41718 78935 71542 14866 78923 51347 5735 72300 22252 45894 7633 22331 78127 95427 70016 73945 31634 22352 44906 71181 39172 84234 58206 23874 38699 77451 3855 45904 57001 78543 570 74979 65361 83923 67612 87820 27955 73316 77213 46782 42103 83903 45204 37992 39791 71724 95273 64945 56881 88073 10246 35798 14987 83335 47144 95067 50014 83028 49771 12183 76189 71204 21386 79884 30132 3908 17499 28839 38675 44139 27828 6597 8699 94270 33782 92343 9726 78034 47582 68603 87447 91637 18318 36900 77402 52654 16160 26697 18264 31081 60367 82019 84522 18080 67907 41704 84348 71895 19139 66978 65507 78939 74586 64271 46053 6709 98203 10046 33543 30199 59720 64261 46272 56693 29560 9581 87518 61303 523
# ...

# %%
a = [0, 1]

# %%
for i in a[2:]:
    print(i)

# %%
a.sort()

# %%
a
# Out:
# [0, 2, 4, 5, 7]
